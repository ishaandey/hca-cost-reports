# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

# %%
locs = pd.read_csv('locations-controller.csv')

# %%
locs.columns
# Out:
# Index(['Type', 'Id', 'Title', 'Coid', 'PrimaryColor', 'PrimaryGradient',
#        'SecondaryColor', 'SecondaryGradient', 'Address1', 'Address2', 'City',
#        'State', 'Default', 'Zip', 'PrimaryPhone', 'Fax', 'AdditionalText',
#        'Latitude', 'Longitude', 'Photo1', 'Photo2', 'BackgroundImage',
#        'BuildingType', 'ErFeed', 'Link', 'CtaButton', 'SecondaryCtaButton',
#        'SortOrder', 'Hours', 'StarRating'],
#       dtype='object')

# %%
locs_sub = locs[['Type','Title','Address1','City','State','Zip','Latitude','Longitude','PrimaryPhone','BuildingType']]

# %%
locs_sub.to_csv('hospital-locations.csv',index=False)

# %%
locs_sub
# Out:
#          Type                                 Title                Address1  \
# 0    Building              Alaska Regional Hospital        2801 DeBarr Road
# 1    Building                  Angel Medical Center    120 Riverview Street
# 2    Building  Aventura Hospital and Medical Center     20900 Biscayne Blvd
# 3    Building           Bayview Behavioral Hospital    6629 Wooldridge Road
# 4    Building        Belton Regional Medical Center     17065 S. 71 Highway
# ..        ...                                   ...                     ...
# 197  Building                 West Florida Hospital        8383 N Davis Hwy
# 198  Building  West Hills Hospital & Medical Center  7300 Medical Center Dr
# 199  Building        West Marion Community Hospital         4600 SW 46th Ct
# 200  Building            West Valley Medical Center      1717 Arlington Ave
# 201  Building      Westside Regional Medical Center     8201 W Broward Blvd
#
# ...
